# %% [markdown]
# <center>
# <img src="../logo.png" height="900">
# </center>
#
#
# #  Временные ряды: SARIMA
#
# В этой тетрадке мы продолжим знакомиться с моделями для прогнозирования временных рядов и поговорим про SARIMA.

# %%
import numpy as np
import pandas as pd

from scipy import stats 
import statsmodels.api as sm

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

import seaborn as sns

# %matplotlib inline

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
def mape(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# # 1. Тест на стационарность
#
# Чтобы бороться с нестационарностью, нужно знать её в лицо. Для этого обратимся к белому шуму и случайному блужданию, чтобы выяснить как попасть из одного в другое. Попробуем сгенерировать несколько авторегрессий и проверить гипотезу о их стационарности: $y_t = \beta y_{t-1} + u_t$

# %%
from statsmodels.tsa.stattools import adfuller, kpss

def plotProcess(n_samples=1000, beta=0):
    y = u = np.random.normal(size=n_samples)
    for t in range(n_samples):
        y[t] = beta * y[t-1] + u[t]

    with plt.style.context('bmh'):  
        plt.figure(figsize=(10, 3))
        plt.plot(y)
        p_adf = round(adfuller(y)[1], 3)
        p_kpss = round(kpss(y)[1], 3)
        plt.title(f"Beta: {beta}\n Dickey-Fuller p-value: {p_adf} \n KPSS p-value: {p_kpss}")

# %%
for beta in [0, 0.6, 0.9, 1]:
    plotProcess(beta=beta)

# %% [markdown]
# - На первом графике получился стационарный белый шум, последовательность из независимых нормальных случайных величин с нулевым математическим ожиданием и одинаковой дисперсией.
# - На втором значение $\beta$ увеличилось до $0.6$, в результате чего на графике стали появляться более широкие циклы, но в целом стационарным он быть пока не перестал.
# - Третий график всё сильнее отклоняется от нулевого среднего значения, но всё ещё колеблется вокруг него.
# - Наконец, значение  равное единице дало процесс случайного блуждания — ряд не стационарен. Для него характеристики зависят от времени и мы подолгу задерживаемся по какую-то конкретную сторону от нуля.
#
# Нулевая гипотеза теста Дики-Фуллера — ряд не стационарен, отвергалась на первых трех графиках, и не отверглась на последнем. Для KPSS-теста, где нулевая гипотеза заключается в стационарности ряда, мы видим обратную картину.
#
# Если вычесть из левой и правой части $y_{t-1}$, то получим  $y_t - y_{t-1} = (\beta - 1) y_{t-1} + u_t$, где выражение слева — первые разности. Если $\beta=1$, то первые разности дадут стационарный белый шум $u_t$. Если из нестационарного ряда первыми разностями удаётся получить стационарный, то он называется интегрированным первого порядка. Это записывают как $y_t \sim I(1)$.
#
# Стоит сказать, что не всегда для получения стационарного ряда хватает первых разностей, так как процесс может быть интегрированным с более высоким порядком (иметь несколько единичных корней). Здравый смысл подсказывает, что больше двух единичных корней не бывает. Так как первая разность - это приросты, а вторая ускорения (по аналогии с производными). Из-за этого в ряды $y_t \sim I(3)$ статистики не верят.
#
# При этом $y_t \sim I(2)$ ряды в рироде бывают. Один из примеров такого ряда - цены. Первая разность цен это инфляция, а ряд инфляции в теории считается нестационарным, так как может быть выражен через нестационарные процентные ставки.

# %% [markdown]
# # 2. Данные

# %%
ads = pd.read_csv('data/ads.csv', index_col=['Time'], parse_dates=['Time']).asfreq('H')
print(ads.shape)
ads.head()
# Out:
# (216, 1)
#                         Ads
# Time
# 2017-09-13 00:00:00   80115
# 2017-09-13 01:00:00   79885
# 2017-09-13 02:00:00   89325
# 2017-09-13 03:00:00  101930
# 2017-09-13 04:00:00  121630

# %%
from sktime.utils.plotting import plot_series

y = ads.Ads/10**3  # в тысячах :)

plot_series(y)
plt.title('Просмотры рекламы (тыс. часов за час)', fontsize=20, color='black')
plt.tick_params(axis = 'both', which = 'major', labelsize = 14);

# %% [markdown]
# Тесты выдают не только `p_value`, но и расчитанные исследователями-создателями критические значения. У тестов нестандартные распределения. Число лагов для тестирования подбирается автоматически по информационному критерию.

# %%
adfuller(y, regression='c', autolag='AIC')
# Out:
# (-7.089633890638526,
#  4.444803688622158e-10,
#  9,
#  206,
#  {'1%': -3.4624988216864776,
#   '5%': -2.8756749365852587,
#   '10%': -2.5743041549627677},
#  1447.702409531276)

# %%
kpss(y, regression='c')
# Out:
# (0.085158794355902,
#  0.1,
#  15,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# Обратите внимание, что тесты можно проводить против разных альтернатив, в зависимости от того, что мы видим в данных:
#
# ```
#     * "c" : constant only (default).
#     * "ct" : constant and trend.
#     * "ctt" : constant, and linear and quadratic trend.
#     * "nc" : no constant, no trend.
# ```
#
# В данном случае мы видим только константу, так как ряд колеблется вокруг ненулевого среднего. Посмотрим на ещё один ряд.

# %%
currency = pd.read_csv('data/currency.csv', index_col=['Time'], parse_dates=['Time'])
print(currency.shape)

plt.figure(figsize=(15, 6))
z = currency.GEMS_GEMS_SPENT/10**3  # в тысячах :)

plot_series(z)
plt.title('Покупки внутри игры (тыс. долларов)', fontsize=20, color='black')
plt.tick_params(axis = 'both', which = 'major', labelsize = 14);
# Out:
# (300, 1)

# %% [markdown]
# Тут в ряде заметны тренд и константа. Поэтому мы выбираем в качестве базовой другую модель.

# %%
adfuller(y, regression='ct', autolag='AIC')
# Out:
# (-7.287687384765353,
#  3.128981731281974e-09,
#  9,
#  206,
#  {'1%': -4.003402336644926,
#   '5%': -3.4320207442298027,
#   '10%': -3.1396965086430555},
#  1447.5157288829562)

# %% [markdown]
# Видим, что ряд стационарен. Если выбрать неверную спецификацию теста, можно ошибиться с выводами:

# %%
adfuller(y, regression='nc', autolag='AIC')
# Out:
# (-0.6216993344800491,
#  0.4455388673196825,
#  12,
#  203,
#  {'1%': -2.5768418078575066,
#   '5%': -1.9424010772432776,
#   '10%': -1.6155744530123806},
#  1482.4285026259213)

# %% [markdown]
# # 3. Автоарима
#
# Попробуем оценить на наших данных SARIMA-модель. Делать это будем в рамках [пакета `pmdarima`](https://alkaline-ml.com/pmdarima/user_guide.html)

# %%
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.base import ForecastingHorizon

y_train, y_test = temporal_train_test_split(y, test_size=48)
fh = ForecastingHorizon(y_test.index, is_relative=False)

plot_series(y_train, y_test, labels=["y_train", "y_test"])
print(y_train.shape[0], y_test.shape[0])
# Out:
# 168 48

# %%
import pmdarima as pm
from pmdarima import model_selection

arima_model = pm.auto_arima(
    
    y_train,
    start_p=1, start_q=1,
    max_p=5, max_q=5, 
    
    seasonal=True, m=24,
    start_P=0, start_Q=0,
    max_P = 2, max_Q = 2,
    
    max_D=2, max_d=2,
    alpha=0.05,
    test='kpss',
    seasonal_test='ocsb',    
    
    trace=True,
    error_action='ignore',  
    suppress_warnings=True, 
    stepwise=False, 
    n_fits=100,
    information_criterion='bic',
    out_of_sample_size=7
    
    # Можно делать перебор гипер-параметров 
    # на основе метрики на тестовой выборке
    #scoring='mae',
)
# Out:
#  ARIMA(0,0,0)(0,0,0)[24] intercept   : BIC=1600.196, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,1)[24] intercept   : BIC=1499.817, Time=0.42 sec
#  ARIMA(0,0,0)(0,0,2)[24] intercept   : BIC=1453.603, Time=2.12 sec
#  ARIMA(0,0,0)(1,0,0)[24] intercept   : BIC=1388.180, Time=0.80 sec
#  ARIMA(0,0,0)(1,0,1)[24] intercept   : BIC=1476.485, Time=0.71 sec
#  ARIMA(0,0,0)(1,0,2)[24] intercept   : BIC=1858.949, Time=4.90 sec
#  ARIMA(0,0,0)(2,0,0)[24] intercept   : BIC=1402.763, Time=4.88 sec
#  ARIMA(0,0,0)(2,0,1)[24] intercept   : BIC=1398.436, Time=3.96 sec
#  ARIMA(0,0,0)(2,0,2)[24] intercept   : BIC=1400.305, Time=4.99 sec
#  ARIMA(0,0,1)(0,0,0)[24] intercept   : BIC=1434.233, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,1)[24] intercept   : BIC=1350.698, Time=0.56 sec
#  ARIMA(0,0,1)(0,0,2)[24] intercept   : BIC=1319.072, Time=3.04 sec
#  ARIMA(0,0,1)(1,0,0)[24] intercept   : BIC=1268.207, Time=0.84 sec
#  ARIMA(0,0,1)(1,0,1)[24] intercept   : BIC=1350.352, Time=1.14 sec
#  ARIMA(0,0,1)(1,0,2)[24] intercept   : BIC=1855.597, Time=8.02 sec
#  ARIMA(0,0,1)(2,0,0)[24] intercept   : BIC=1321.887, Time=4.12 sec
#  ARIMA(0,0,1)(2,0,1)[24] intercept   : BIC=1327.048, Time=5.07 sec
#  ARIMA(0,0,1)(2,0,2)[24] intercept   : BIC=1283.979, Time=5.86 sec
#  ARIMA(0,0,2)(0,0,0)[24] intercept   : BIC=1324.000, Time=0.21 sec
#  ARIMA(0,0,2)(0,0,1)[24] intercept   : BIC=1271.044, Time=1.28 sec
#  ARIMA(0,0,2)(0,0,2)[24] intercept   : BIC=1247.108, Time=5.14 sec
#  ARIMA(0,0,2)(1,0,0)[24] intercept   : BIC=1210.408, Time=0.91 sec
#  ARIMA(0,0,2)(1,0,1)[24] intercept   : BIC=1205.214, Time=1.88 sec
#  ARIMA(0,0,2)(1,0,2)[24] intercept   : BIC=2505.017, Time=12.84 sec
#  ARIMA(0,0,2)(2,0,0)[24] intercept   : BIC=1236.034, Time=4.89 sec
#  ARIMA(0,0,2)(2,0,1)[24] intercept   : BIC=1249.535, Time=6.70 sec
#  ARIMA(0,0,3)(0,0,0)[24] intercept   : BIC=1286.441, Time=0.32 sec
#  ARIMA(0,0,3)(0,0,1)[24] intercept   : BIC=1237.607, Time=1.05 sec
#  ARIMA(0,0,3)(0,0,2)[24] intercept   : BIC=1216.257, Time=5.16 sec
#  ARIMA(0,0,3)(1,0,0)[24] intercept   : BIC=1200.571, Time=1.15 sec
#  ARIMA(0,0,3)(1,0,1)[24] intercept   : BIC=1239.394, Time=2.42 sec
#  ARIMA(0,0,3)(2,0,0)[24] intercept   : BIC=1281.451, Time=5.88 sec
#  ARIMA(0,0,4)(0,0,0)[24] intercept   : BIC=1261.015, Time=0.43 sec
#  ARIMA(0,0,4)(0,0,1)[24] intercept   : BIC=1219.154, Time=2.24 sec
#  ARIMA(0,0,4)(1,0,0)[24] intercept   : BIC=1313.660, Time=1.51 sec
#  ARIMA(0,0,5)(0,0,0)[24] intercept   : BIC=1254.142, Time=0.48 sec
#  ARIMA(1,0,0)(0,0,0)[24] intercept   : BIC=1319.347, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,1)[24] intercept   : BIC=1246.178, Time=0.58 sec
#  ARIMA(1,0,0)(0,0,2)[24] intercept   : BIC=1210.603, Time=2.22 sec
#  ARIMA(1,0,0)(1,0,0)[24] intercept   : BIC=1173.938, Time=0.81 sec
#  ARIMA(1,0,0)(1,0,1)[24] intercept   : BIC=1157.887, Time=1.22 sec
#  ARIMA(1,0,0)(1,0,2)[24] intercept   : BIC=1873.375, Time=12.39 sec
#  ARIMA(1,0,0)(2,0,0)[24] intercept   : BIC=1174.936, Time=3.92 sec
#  ARIMA(1,0,0)(2,0,1)[24] intercept   : BIC=1183.000, Time=5.11 sec
#  ARIMA(1,0,0)(2,0,2)[24] intercept   : BIC=1166.746, Time=5.38 sec
#  ARIMA(1,0,1)(0,0,0)[24] intercept   : BIC=1266.715, Time=0.15 sec
#  ARIMA(1,0,1)(0,0,1)[24] intercept   : BIC=1218.105, Time=0.79 sec
#  ARIMA(1,0,1)(0,0,2)[24] intercept   : BIC=1199.129, Time=2.54 sec
#  ARIMA(1,0,1)(1,0,0)[24] intercept   : BIC=1170.344, Time=0.80 sec
#  ARIMA(1,0,1)(1,0,1)[24] intercept   : BIC=1152.715, Time=1.57 sec
#  ARIMA(1,0,1)(1,0,2)[24] intercept   : BIC=1824.673, Time=7.87 sec
#  ARIMA(1,0,1)(2,0,0)[24] intercept   : BIC=1170.264, Time=4.10 sec
#  ARIMA(1,0,1)(2,0,1)[24] intercept   : BIC=1164.074, Time=5.80 sec
#  ARIMA(1,0,2)(0,0,0)[24] intercept   : BIC=1247.252, Time=0.18 sec
#  ARIMA(1,0,2)(0,0,1)[24] intercept   : BIC=1209.526, Time=1.22 sec
#  ARIMA(1,0,2)(0,0,2)[24] intercept   : BIC=1192.331, Time=3.42 sec
#  ARIMA(1,0,2)(1,0,0)[24] intercept   : BIC=1166.475, Time=1.26 sec
#  ARIMA(1,0,2)(1,0,1)[24] intercept   : BIC=1165.560, Time=1.90 sec
#  ARIMA(1,0,2)(2,0,0)[24] intercept   : BIC=1164.438, Time=5.24 sec
#  ARIMA(1,0,3)(0,0,0)[24] intercept   : BIC=1250.814, Time=0.21 sec
#  ARIMA(1,0,3)(0,0,1)[24] intercept   : BIC=1211.479, Time=1.42 sec
#  ARIMA(1,0,3)(1,0,0)[24] intercept   : BIC=1169.049, Time=1.51 sec
#  ARIMA(1,0,4)(0,0,0)[24] intercept   : BIC=1250.038, Time=0.29 sec
#  ARIMA(2,0,0)(0,0,0)[24] intercept   : BIC=1237.318, Time=0.12 sec
#  ARIMA(2,0,0)(0,0,1)[24] intercept   : BIC=1200.718, Time=0.75 sec
#  ARIMA(2,0,0)(0,0,2)[24] intercept   : BIC=1188.369, Time=2.30 sec
#  ARIMA(2,0,0)(1,0,0)[24] intercept   : BIC=1165.940, Time=1.25 sec
#  ARIMA(2,0,0)(1,0,1)[24] intercept   : BIC=1168.531, Time=1.37 sec
#  ARIMA(2,0,0)(1,0,2)[24] intercept   : BIC=inf, Time=nan sec
#  ARIMA(2,0,0)(2,0,0)[24] intercept   : BIC=1165.458, Time=4.72 sec
#  ARIMA(2,0,0)(2,0,1)[24] intercept   : BIC=1175.307, Time=5.74 sec
#  ARIMA(2,0,1)(0,0,0)[24] intercept   : BIC=1242.452, Time=0.12 sec
#  ARIMA(2,0,1)(0,0,1)[24] intercept   : BIC=1205.182, Time=0.94 sec
#  ARIMA(2,0,1)(0,0,2)[24] intercept   : BIC=1191.620, Time=2.95 sec
#  ARIMA(2,0,1)(1,0,0)[24] intercept   : BIC=1182.688, Time=1.38 sec
#  ARIMA(2,0,1)(1,0,1)[24] intercept   : BIC=1173.565, Time=1.60 sec
#  ARIMA(2,0,1)(2,0,0)[24] intercept   : BIC=1183.433, Time=5.29 sec
#  ARIMA(2,0,2)(0,0,0)[24] intercept   : BIC=1246.700, Time=0.21 sec
#  ARIMA(2,0,2)(0,0,1)[24] intercept   : BIC=1209.362, Time=1.63 sec
#  ARIMA(2,0,2)(1,0,0)[24] intercept   : BIC=1170.771, Time=1.49 sec
#  ARIMA(2,0,3)(0,0,0)[24] intercept   : BIC=1241.932, Time=0.48 sec
#  ARIMA(3,0,0)(0,0,0)[24] intercept   : BIC=1242.434, Time=0.17 sec
#  ARIMA(3,0,0)(0,0,1)[24] intercept   : BIC=1204.923, Time=1.18 sec
#  ARIMA(3,0,0)(0,0,2)[24] intercept   : BIC=1190.726, Time=3.15 sec
#  ARIMA(3,0,0)(1,0,0)[24] intercept   : BIC=1168.626, Time=1.89 sec
#  ARIMA(3,0,0)(1,0,1)[24] intercept   : BIC=1169.060, Time=1.93 sec
#  ARIMA(3,0,0)(2,0,0)[24] intercept   : BIC=1169.085, Time=6.51 sec
#  ARIMA(3,0,1)(0,0,0)[24] intercept   : BIC=1247.544, Time=0.24 sec
#  ARIMA(3,0,1)(0,0,1)[24] intercept   : BIC=1209.305, Time=1.51 sec
#  ARIMA(3,0,1)(1,0,0)[24] intercept   : BIC=1175.141, Time=1.82 sec
#  ARIMA(3,0,2)(0,0,0)[24] intercept   : BIC=1250.142, Time=0.39 sec
#  ARIMA(4,0,0)(0,0,0)[24] intercept   : BIC=1247.096, Time=0.25 sec
#  ARIMA(4,0,0)(0,0,1)[24] intercept   : BIC=1209.814, Time=1.26 sec
#  ARIMA(4,0,0)(1,0,0)[24] intercept   : BIC=1170.693, Time=2.01 sec
#  ARIMA(4,0,1)(0,0,0)[24] intercept   : BIC=1250.493, Time=0.39 sec
#  ARIMA(5,0,0)(0,0,0)[24] intercept   : BIC=1250.130, Time=0.25 sec
# Total fit time: 236.930 seconds

# %%
print(arima_model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(1, 0, 1)x(1, 0, 1, 24)   Log Likelihood                -560.986
# Date:                            Mon, 30 Nov 2020   AIC                           1133.971
# Time:                                    01:37:55   BIC                           1152.715
# Sample:                                         0   HQIC                          1141.579
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.6322      0.391      1.615      0.106      -0.135       1.399
# ar.L1          0.7997      0.053     14.989      0.000       0.695       0.904
# ma.L1          0.2673      0.068      3.953      0.000       0.135       0.400
# ar.S.L24       0.9738      0.015     66.625      0.000       0.945       1.002
# ma.S.L24      -0.6900      0.076     -9.119      0.000      -0.838      -0.542
# sigma2        37.7166      3.988      9.458      0.000      29.901      45.532
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.56   Jarque-Bera (JB):                 1.39
# Prob(Q):                              0.46   Prob(JB):                         0.50
# Heteroskedasticity (H):               1.12   Skew:                             0.08
# Prob(H) (two-sided):                  0.67   Kurtosis:                         3.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
y_pred, pred_ci = arima_model.predict(
    n_periods=48, 
    return_conf_int=True, 
    alpha=0.05
)

mape(y_pred, y_test)
# Out:
# 5.484026403387965

# %%
df_forecast = pd.DataFrame({'y_pred': y_pred, 'ci_lower': pred_ci[:,0], 'ci_upper': pred_ci[:,1]})
df_forecast.index = fh
df_forecast.head()
# Out:
#                          y_pred   ci_lower    ci_upper
# 2017-09-20 00:00:00   77.807981  65.747562   89.868400
# 2017-09-20 01:00:00   77.738273  60.112611   95.363935
# 2017-09-20 02:00:00   85.023227  64.619358  105.427096
# 2017-09-20 03:00:00   97.198042  75.200660  119.195423
# 2017-09-20 04:00:00  116.462307  93.503766  139.420848

# %%
fig, ax = plot_series(y_train, y_test, df_forecast.y_pred, labels=["y_train", "y_test", "y_pred"]);
ax.fill_between(
    ax.get_lines()[-1].get_xdata(),
    df_forecast["ci_lower"],
    df_forecast["ci_upper"],
    alpha=0.2,
    color=ax.get_lines()[-1].get_c(),
    label=f"95% prediction intervals",
)
ax.legend(loc='lower left');

# %% [markdown]
# Посмотрим на графики для диагностики модели. Автокорреляций нет, математическое ожидание равно нулю. Дисперсия постоянна. Распределение остатков нормально. Приятно.

# %%
arima_model.plot_diagnostics(figsize=(10, 8));

# %% [markdown]
# На самом деле ровно эта же модель вшита в пакет `sktime`, но в урезанном виде. Напомню, что этот пакет только разрабатывается и его великое будущее впереди.

# %% [markdown]
# # 4. Трансформация данных
#
# В рамках пакета можно делать трансформацию данных и собирать пайплайны также, как и в sklearn. Например, перед обучением модели можно сделать преобразование Бокса-Кокса. Его здесь обычно используют для того, чтобы стабилизировать дисперсию остатков и сделать их нормальными.

# %%
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer

pipeline = Pipeline([
    ("boxcox", BoxCoxEndogTransformer()),
    ("model", pm.AutoARIMA(seasonal=True, suppress_warnings=True))
])

pipeline.fit(y_train)
pipeline.predict(5)
# Out:
# array([ 77.42356325,  83.43529643,  93.37397193, 104.16268218,
#        113.81109217])

# %%
pipeline.steps[1][1].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  168
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                -742.622
# Date:                Mon, 30 Nov 2020   AIC                           1493.244
# Time:                        01:37:57   BIC                           1505.740
# Sample:                             0   HQIC                          1498.315
#                                 - 168
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     35.3897      7.333      4.826      0.000      21.018      49.762
# ar.L1          1.4846      0.068     21.728      0.000       1.351       1.618
# ar.L2         -0.6364      0.058    -11.032      0.000      -0.749      -0.523
# sigma2       397.9566     49.728      8.003      0.000     300.491     495.422
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                17.85
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.09   Skew:                            -0.75
# Prob(H) (two-sided):                  0.75   Kurtosis:                         3.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## Материалы:
#
# - [Документация пакета pmdarima с примерами использования](https://alkaline-ml.com/pmdarima/quickstart.html)
# - [Гайд по ARIMA от statsmodels](https://www.statsmodels.org/dev/examples/notebooks/generated/statespace_sarimax_stata.html)
