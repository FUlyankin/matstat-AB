# %% [markdown]
# <center>
# <img src="logo.png" height="900">
# </center>
#
# #  Работа с логами
#
# __Логи__ - это файлы с записью различных событий в хронологическом порядке. Обычно, все действия пользователя в различных сервисах подробно логируются. Именно по логам в дальнейшем аналитики считают различные метрики и строят модели.
#
# В этой тетрадке мы проанализируем [логи покупок онлайн-магазина, продающего атрибутику компании Google.](https://www.kaggle.com/c/ga-customer-revenue-prediction/data?select=train.csv)
#
# __Цели:__
#
# - Построить несколько пользовательских метрик: посещаемость, средняя выручка, возвращаемость
# - Проанализровать как ведут себя пользовательские метрики в разбивке по разным источникам (браузеры, устройства и тп)
# - Сделать исходя из этого анализа несколько мудрых маркетинговых выводов

# %%
import numpy as np         # библиотека для матриц и математики
import pandas as pd        # библиотека для работы с табличками
from scipy import stats    # модуль для работы со статистикой

import matplotlib.pyplot as plt
import seaborn as sns

# стиль графиков
# plt.style.use('ggplot')    
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# # 1. Данные
#
# > Познакомимся с логом, с которым мы будем работать. Приведём его в удобный для строительства метрик вид.

# %%
df = pd.read_csv('google_log.csv', sep='\t')

df['totals.transactionRevenue'] = df['totals.transactionRevenue']/10**6

print(df.shape)
df.head()
# Out:
# (903653, 24)
#        date        fullVisitorId                       sessionId  \
# 0  20160902  1131660440785968503  1131660440785968503_1472830385
# 1  20160902   377306020877927890   377306020877927890_1472880147
# 2  20160902  3895546263509774583  3895546263509774583_1472865386
# 3  20160902  4763447161404445595  4763447161404445595_1472881213
# 4  20160902    27294437909732085    27294437909732085_1472822600
#
#   channelGrouping  visitStartTime device.browser device.operatingSystem  \
# 0  Organic Search      1472830385         Chrome                Windows
# 1  Organic Search      1472880147        Firefox              Macintosh
# 2  Organic Search      1472865386         Chrome                Windows
# 3  Organic Search      1472881213     UC Browser                  Linux
# 4  Organic Search      1472822600         Chrome                Android
#
#    device.isMobile device.deviceCategory geoNetwork.subContinent  ...  \
# 0            False               desktop            Western Asia  ...
# 1            False               desktop             Australasia  ...
# 2            False               desktop         Southern Europe  ...
# 3            False               desktop          Southeast Asia  ...
# 4             True                mobile         Northern Europe  ...
#
#   totals.pageviews totals.transactionRevenue trafficSource.source  \
# 0              1.0                       NaN               google
# 1              1.0                       NaN               google
# 2              1.0                       NaN               google
# 3              1.0                       NaN               google
# 4              1.0                       NaN               google
#
#    trafficSource.medium  trafficSource.keyword  \
# 0               organic         (not provided)
# 1               organic         (not provided)
# 2               organic         (not provided)
# 3               organic        google + online
# 4               organic         (not provided)
#
#    trafficSource.adwordsClickInfo.adNetworkType  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd trafficSource.adContent
# 0                                      NaN                     NaN
# 1                                      NaN                     NaN
# 2                                      NaN                     NaN
# 3                                      NaN                     NaN
# 4                                      NaN                     NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# __Описание колонок:__
#
#
# - `date` дата посещения сайта (рассматривается период с 20160801 по 20170801
# - `fullVisitorId` уникальный id пользователя
# - `sessionId` уникальный id одной пользовательской сессии
# - `channelGrouping` откуда произошёл переход
# - `visitStartTime` timestamp начала визита
# - `device.browser` браузер визита
# - `device.operatingSystem` операционная система устройства
# - `device.isMobile` является ли устройство мобильным
# - `device.deviceCategory` тип устройства (айпад, компьютер, мобильный телефон)
# - `geoNetwork.subContinent` часть света пользователя
# - `geoNetwork.country` страна пользователя
# - `geoNetwork.region` регион пользователя
# - `geoNetwork.city` город пользователя
# - `totals.hits` похоже что это действия на сайте, но это неточно
# - `totals.pageviews` просмотры страниц
# - `totals.transactionRevenue` выручка с покупки
# - `trafficSource.source` источник трафика
# - `trafficSource.medium` более высокоуровневый источник трафика
# - `trafficSource.keyword` ключевые слова из поиска
# - `trafficSource.adwordsClickInfo.adNetworkType` несколько переменных с дополнительной информацией из adwords
# - `trafficSource.adwordsClickInfo.page`
# - `trafficSource.adwordsClickInfo.slot`
# - `trafficSource.adwordsClickInfo.isVideoAd`
# - `trafficSource.adContent`

# %% [markdown]
# Посмотрим на процент пропусков.

# %%
100*df.isnull().sum()/df.shape[0]
# Out:
# date                                             0.000000
# fullVisitorId                                    0.000000
# sessionId                                        0.000000
# channelGrouping                                  0.000000
# visitStartTime                                   0.000000
# device.browser                                   0.000000
# device.operatingSystem                           0.000000
# device.isMobile                                  0.000000
# device.deviceCategory                            0.000000
# geoNetwork.subContinent                          0.000000
# geoNetwork.country                               0.000000
# geoNetwork.region                                0.000000
# geoNetwork.city                                  0.000000
# totals.hits                                      0.000000
# totals.pageviews                                 0.011066
# totals.transactionRevenue                       98.725728
# trafficSource.source                             0.000000
# trafficSource.medium                             0.000000
# trafficSource.keyword                           55.655102
# trafficSource.adwordsClickInfo.adNetworkType    97.625195
# trafficSource.adwordsClickInfo.page             97.625195
# trafficSource.adwordsClickInfo.slot             97.625195
# trafficSource.adwordsClickInfo.isVideoAd        97.625195
# trafficSource.adContent                         98.788694
# dtype: float64

# %% [markdown]
# Визуализируем пропуски в различных колонках. Сделаем случайную подвыборку в $5000$ строк и раскрасим пропуски в жёлтый.

# %%
fig, ax = plt.subplots(figsize=(15,8))

sns_heatmap = sns.heatmap(df.sample(5000).isnull(), 
                          yticklabels=False, 
                          cbar=False, 
                          cmap='viridis')

# %% [markdown]
# Посмотрим на описательные статистики.

# %%
df.describe()
# Out:
#                date  visitStartTime    totals.hits  totals.pageviews  \
# count  9.036530e+05    9.036530e+05  903653.000000     903553.000000
# mean   2.016589e+07    1.485007e+09       4.596538          3.849764
# std    4.697698e+03    9.022124e+06       9.641437          7.025274
# min    2.016080e+07    1.470035e+09       1.000000          1.000000
# 25%    2.016103e+07    1.477561e+09       1.000000          1.000000
# 50%    2.017011e+07    1.483949e+09       2.000000          1.000000
# 75%    2.017042e+07    1.492759e+09       4.000000          4.000000
# max    2.017080e+07    1.501657e+09     500.000000        469.000000
#
#        totals.transactionRevenue  trafficSource.adwordsClickInfo.page
# count               11515.000000                         21460.000000
# mean                  133.744789                             1.008108
# std                   448.285227                             0.173584
# min                     0.010000                             1.000000
# 25%                    24.930000                             1.000000
# 50%                    49.450000                             1.000000
# 75%                   107.655000                             1.000000
# max                 23129.500000                            14.000000

# %%
df.describe(include='object')
# Out:
#               fullVisitorId                       sessionId channelGrouping  \
# count                903653                          903653          903653
# unique               731421                          902755               8
# top     1957458976293878100  7344096048001407659_1476946195  Organic Search
# freq                    252                               2          381561
#
#        device.browser device.operatingSystem device.deviceCategory  \
# count          903653                 903653                903653
# unique             54                     20                     3
# top            Chrome                Windows               desktop
# freq           620364                 350072                664479
#
#        geoNetwork.subContinent geoNetwork.country  \
# count                   903653             903653
# unique                      23                222
# top           Northern America      United States
# freq                    390657             364744
#
#                     geoNetwork.region                geoNetwork.city  \
# count                          903653                         903653
# unique                            376                            649
# top     not available in demo dataset  not available in demo dataset
# freq                           508229                         508229
#
#        trafficSource.source trafficSource.medium trafficSource.keyword  \
# count                903653               903653                400724
# unique                  380                    7                  3659
# top                  google              organic        (not provided)
# freq                 400788               381561                366363
#
#        trafficSource.adwordsClickInfo.adNetworkType  \
# count                                         21460
# unique                                            2
# top                                   Google Search
# freq                                          21453
#
#        trafficSource.adwordsClickInfo.slot  \
# count                                21460
# unique                                   2
# top                                    Top
# freq                                 20956
#
#        trafficSource.adwordsClickInfo.isVideoAd        trafficSource.adContent
# count                                     21460                          10946
# unique                                        1                             44
# top                                       False  Google Merchandise Collection
# freq                                      21460                           5122

# %% [markdown]
# Заведём несколько переменных со временем.

# %%
df["date"].dtype
# Out:
# dtype('int64')

# %%
df['date'][:10]
# Out:
# 0    20160902
# 1    20160902
# 2    20160902
# 3    20160902
# 4    20160902
# 5    20160902
# 6    20160902
# 7    20160902
# 8    20160902
# 9    20160902
# Name: date, dtype: int64

# %%
df["date"] = pd.to_datetime(df["date"], format="%Y%m%d")
df["date"][:10]
# Out:
# 0   2016-09-02
# 1   2016-09-02
# 2   2016-09-02
# 3   2016-09-02
# 4   2016-09-02
# 5   2016-09-02
# 6   2016-09-02
# 7   2016-09-02
# 8   2016-09-02
# 9   2016-09-02
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# Модуль `dt` включает в себя довольно много встроенных в pandas методов для работы со временем.

# %%
df['month'] = df['date'].apply(lambda w: w.strftime('%Y-%m'))
df['month'][:10]
# Out:
# 0    2016-09
# 1    2016-09
# 2    2016-09
# 3    2016-09
# 4    2016-09
# 5    2016-09
# 6    2016-09
# 7    2016-09
# 8    2016-09
# 9    2016-09
# Name: month, dtype: object

# %%
df["visitDay"] = df['date'].dt.day
df["visitDay"][:10]
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# 5    2
# 6    2
# 7    2
# 8    2
# 9    2
# Name: visitDay, dtype: int64

# %%
df["visitDay"] = df['date'].dt.day             # день визита
df["visitMonth"] = df['date'].dt.month         # месяц визита

df["visitWeekday"] = df['date'].dt.weekday     # выходные
df["visitWeeknum"] = df['date'].dt.weekofyear  # порядковый номер недели в году

# начало и конец месяца
df["is_month_start"] = df['date'].dt.is_month_start
df["is_month_end"] = df['date'].dt.is_month_end

# %%
df['visitStartTime'][:10]
# Out:
# 0    1472830385
# 1    1472880147
# 2    1472865386
# 3    1472881213
# 4    1472822600
# 5    1472807194
# 6    1472817241
# 7    1472812602
# 8    1472805784
# 9    1472812272
# Name: visitStartTime, dtype: int64

# %%
from datetime import datetime
datetime.fromtimestamp(1472812272).minute
# Out:
# 31

# %%
# час визита
df['visitHour'] = (df['visitStartTime'].apply(
    lambda x: datetime.fromtimestamp(x).hour))

# время визита с точностью до секунды
df['ts'] = df['visitStartTime'].apply(lambda x: 
                                      pd.datetime.fromtimestamp(x))

# %% [markdown]
# # 2. Возвращаемость и посещаемость
#
# > Проанализируем что происходит с посещаемостью сайта и возвращаемостью пользователей.

# %%
df.head()
# Out:
#         date        fullVisitorId                       sessionId  \
# 0 2016-09-02  1131660440785968503  1131660440785968503_1472830385
# 1 2016-09-02   377306020877927890   377306020877927890_1472880147
# 2 2016-09-02  3895546263509774583  3895546263509774583_1472865386
# 3 2016-09-02  4763447161404445595  4763447161404445595_1472881213
# 4 2016-09-02    27294437909732085    27294437909732085_1472822600
#
#   channelGrouping  visitStartTime device.browser device.operatingSystem  \
# 0  Organic Search      1472830385         Chrome                Windows
# 1  Organic Search      1472880147        Firefox              Macintosh
# 2  Organic Search      1472865386         Chrome                Windows
# 3  Organic Search      1472881213     UC Browser                  Linux
# 4  Organic Search      1472822600         Chrome                Android
#
#    device.isMobile device.deviceCategory geoNetwork.subContinent  ...  \
# 0            False               desktop            Western Asia  ...
# 1            False               desktop             Australasia  ...
# 2            False               desktop         Southern Europe  ...
# 3            False               desktop          Southeast Asia  ...
# 4             True                mobile         Northern Europe  ...
#
#   trafficSource.adContent    month visitDay  visitMonth  visitWeekday  \
# 0                     NaN  2016-09        2           9             4
# 1                     NaN  2016-09        2           9             4
# 2                     NaN  2016-09        2           9             4
# 3                     NaN  2016-09        2           9             4
# 4                     NaN  2016-09        2           9             4
#
#    visitWeeknum is_month_start is_month_end visitHour                  ts
# 0            35          False        False        15 2016-09-02 15:33:05
# 1            35          False        False         5 2016-09-03 05:22:27
# 2            35          False        False         1 2016-09-03 01:16:26
# 3            35          False        False         5 2016-09-03 05:40:13
# 4            35          False        False        13 2016-09-02 13:23:20
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 2.1 Сколько людей пользуются магазином в день/месяц?
#
# Посчитаем уникальное число пользователей для каждого дня.

# %%
# для большей читаемости кода
df_day = (
    df.groupby('date')
    .agg({'fullVisitorId': 'nunique'})
    .sort_values('date')
)

df_day.head()
# Out:
#             fullVisitorId
# date
# 2016-08-01           1569
# 2016-08-02           1961
# 2016-08-03           2657
# 2016-08-04           2947
# 2016-08-05           2492

# %%
print(f"Среднее число посетителей в день: {df_day.fullVisitorId.mean()}")
df_day.plot(figsize=(12,6));
# Out:
# Среднее число посетителей в день: 2282.8169398907103

# %%
df_month = (
    df.groupby('month')
    .agg({'fullVisitorId': 'nunique'})
    .sort_values('month')
)

print(f"Среднее число посетителей в месяц: {df_month.fullVisitorId.mean()}")
df_month.plot(figsize=(12,6));
# Out:
# Среднее число посетителей в месяц: 58884.692307692305

# %% [markdown]
# __Выводы:__ Основаня волна посещений магазина наблюдается осенью, летом идёт спад. На дневном графике чётко видна недельная сезонность. В выходные наблюдается спад пользовательской активности.

# %% [markdown]
# ## 2.2 Сколько пользовательских сессий в день?
#
# Для этого нам необходимо сгруппировать по дням посещения и посчитать кол-во пользователей, но не уникальных.

# %%
df_session = (
    df.groupby('date')
    .agg({'fullVisitorId': 'count'})
    .sort_values('date')
)

print(f"Среднее число сессий в день: {df_session.fullVisitorId.mean()}")
df_session.plot(figsize=(12,6));
# Out:
# Среднее число сессий в день: 2468.997267759563

# %% [markdown]
# Видим, что график не сильно отличается от динамики уникальных пользователей. Это позволяет предположить, то что возвращаются люди очень редко. Проверим это.

# %% [markdown]
# ## 2.3 Как часто люди возвращаются?
#
# Чтобы ответить на этот вопрос воспользуемся когортным анализом, за когорту будем брать посетителей зарегистровавшихся в одном месяце.

# %%
first_month_session = (
    df.groupby('fullVisitorId')
    .agg({
        'month':'min',
        'date': 'min',
        'ts': 'min'
    })
)

first_month_session.columns = ['first_invate_month', 'first_invate_day', 'first_invate_ts']
first_month_session.head()
# Out:
#                first_invate_month first_invate_day     first_invate_ts
# fullVisitorId
# 4823595352351             2016-11       2016-11-01 2016-11-01 14:45:10
# 5103959234087             2016-08       2016-08-21 2016-08-21 22:06:48
# 10278554503158            2016-10       2016-10-20 2016-10-21 05:57:46
# 20424342248747            2016-11       2016-11-30 2016-12-01 07:55:01
# 26722803385797            2017-06       2017-06-05 2017-06-05 10:26:34

# %%
df = df.join(first_month_session, on='fullVisitorId')

kogort_month = df[['fullVisitorId', 'month', 'first_invate_month']]
kogort_month.head()
# Out:
#          fullVisitorId    month first_invate_month
# 0  1131660440785968503  2016-09            2016-09
# 1   377306020877927890  2016-09            2016-09
# 2  3895546263509774583  2016-09            2016-09
# 3  4763447161404445595  2016-09            2016-09
# 4    27294437909732085  2016-09            2016-08

# %% [markdown]
# Выделили группы уникальных пользователей по месяцам, построим таблицу, которая покажет возврат пользователей на ресурс.

# %%
retention = kogort_month.pivot_table(
    index='first_invate_month',
    columns='month',
    values = 'fullVisitorId',
    aggfunc='nunique'
)

retention
# Out:
# month               2016-08  2016-09  2016-10  2016-11  2016-12  2017-01  \
# first_invate_month
# 2016-08             62462.0   2204.0   1033.0    602.0    418.0    271.0
# 2016-09                 NaN  58645.0   1936.0    699.0    371.0    212.0
# 2016-10                 NaN      NaN  83411.0   2396.0    753.0    356.0
# 2016-11                 NaN      NaN      NaN  96199.0   2425.0    620.0
# 2016-12                 NaN      NaN      NaN      NaN  62098.0   1643.0
# 2017-01                 NaN      NaN      NaN      NaN      NaN  51329.0
# 2017-02                 NaN      NaN      NaN      NaN      NaN      NaN
# 2017-03                 NaN      NaN      NaN      NaN      NaN      NaN
# 2017-04                 NaN      NaN      NaN      NaN      NaN      NaN
# 2017-05                 NaN      NaN      NaN      NaN      NaN      NaN
# 2017-06                 NaN      NaN      NaN      NaN      NaN      NaN
# 2017-07                 NaN      NaN      NaN      NaN      NaN      NaN
# 2017-08                 NaN      NaN      NaN      NaN      NaN      NaN
#
# month               2017-02  2017-03  2017-04  2017-05  2017-06  2017-07  \
# first_invate_month
# 2016-08               216.0    181.0    139.0    135.0    106.0     89.0
# 2016-09               135.0    112.0    111.0     77.0     55.0     52.0
# 2016-10               253.0    192.0    133.0    108.0     83.0     67.0
# 2016-11               295.0    230.0    168.0    126.0     88.0     78.0
# 2016-12               457.0    304.0    215.0    153.0    105.0     95.0
# 2017-01              1469.0    494.0    275.0    167.0    118.0     89.0
# 2017-02             49248.0   1488.0    450.0    293.0    162.0    113.0
# 2017-03                 NaN  55542.0   1560.0    492.0    239.0    181.0
# 2017-04                 NaN      NaN  53525.0   1504.0    470.0    256.0
# 2017-05                 NaN      NaN      NaN  50934.0   1621.0    551.0
# 2017-06                 NaN      NaN      NaN      NaN  49879.0   1532.0
# 2017-07                 NaN      NaN      NaN      NaN      NaN  55915.0
# 2017-08                 NaN      NaN      NaN      NaN      NaN      NaN
#
# month               2017-08
# first_invate_month
# 2016-08                 3.0
# 2016-09                 1.0
# 2016-10                 1.0
# 2016-11                 NaN
# 2016-12                 3.0
# 2017-01                 3.0
# 2017-02                 2.0
# 2017-03                 4.0
# 2017-04                 3.0
# 2017-05                 9.0
# 2017-06                16.0
# 2017-07                14.0
# 2017-08              2234.0

# %%
plt.figure(figsize=(10, 8))

sns.heatmap(
    retention,
    annot=True,
    fmt='.0f',
    linewidths=1, 
    linecolor='black', 
    cmap="YlGnBu"
);

# %% [markdown]
# Перейдём к процентам.

# %%
first_date = retention.values.diagonal()

for s,row in zip(first_date, retention):
    retention.loc[row] = 100*(retention.loc[row]/s)

plt.figure(figsize=(10, 8))
sns.heatmap(
    retention,
    annot=True,
    fmt='.2f',
    linewidths=1, 
    linecolor='black', 
    cmap="YlGnBu"
);

# %% [markdown]
# Возвраты пользователей крайне малы. Где-то 3% возвращается на второй месяц, а дальше возврат обваливатеся почти до нуля.

# %% [markdown]
# Какая доля визитов относится к месяцу отличному от первого визита?

# %%
(kogort_month.month != kogort_month.first_invate_month).mean()
# Out:
# 0.06694383795549841

# %% [markdown]
# А доля дней?

# %%
(df.date != df.first_invate_day).mean()
# Out:
# 0.13861847412668357

# %% [markdown]
# Видим, что повторные визиты бывают довольно редко.

# %% [markdown]
# # 3. Покупки
#
# > Проанализируем покупки, которые делаются на сайте.
#
# ## 3.1 Когда люди покупают?

# %%
df['totals.transactionRevenue'].isnull().mean()
# Out:
# 0.9872572768529513

# %%
# Процент покупок 
100*(1 - df['totals.transactionRevenue'].isnull().mean())
# Out:
# 1.2742723147048718

# %% [markdown]
# Около 1% пришедших сделали покупку. Такова суровая реальность.

# %%
df_buy = df.dropna(subset=['totals.transactionRevenue'])
df_buy.shape
# Out:
# (11515, 36)

# %% [markdown]
# Посморим на распределение выручки.

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,6))

df_buy['totals.transactionRevenue'].hist(bins=50, log=True, ax=axes[0])
sns.distplot(
    np.log(df_buy['totals.transactionRevenue'] + 1), 
    ax=axes[1], 
    bins=100, 
    kde=True)

axes[0].set_title("Распределение выручки")
axes[0].set_xlabel("Выручка")

axes[1].set_title("Распределение логарифма выручки")
axes[1].set_xlabel("Логарифм выручки")
# Out:
# Text(0.5, 0, 'Логарифм выручки')

# %% [markdown]
# Посмотрим на дату первой покупки. Как часто она отличается от даты первого визита.

# %%
first_day_buy = (
    df_buy.groupby('fullVisitorId')
    .agg({
        'month':'min',
        'date': 'min',
        'ts': 'min'
    })
)

# %%
first_day_buy.head()
# Out:
#                    month       date                  ts
# fullVisitorId
# 213131142648941  2017-04 2017-04-28 2017-04-28 22:41:58
# 435324061339869  2016-10 2016-10-20 2016-10-21 01:33:41
# 562678147042735  2017-04 2017-04-24 2017-04-24 14:27:36
# 585708896049892  2016-12 2016-12-21 2016-12-21 20:59:44
# 670722016498267  2017-07 2017-07-10 2017-07-10 18:00:43

# %%
first_day_buy.columns = ['first_buy_month', 'first_buy_day', 'first_buy_ts']
first_day_buy.head()
# Out:
#                 first_buy_month first_buy_day        first_buy_ts
# fullVisitorId
# 213131142648941         2017-04    2017-04-28 2017-04-28 22:41:58
# 435324061339869         2016-10    2016-10-20 2016-10-21 01:33:41
# 562678147042735         2017-04    2017-04-24 2017-04-24 14:27:36
# 585708896049892         2016-12    2016-12-21 2016-12-21 20:59:44
# 670722016498267         2017-07    2017-07-10 2017-07-10 18:00:43

# %%
df_buy = df_buy.join(first_day_buy, on='fullVisitorId')
df_buy.head()
# Out:
#           date        fullVisitorId                       sessionId  \
# 752 2016-09-02  6194193421514403509  6194193421514403509_1472843572
# 753 2016-09-02  5327166854580374902  5327166854580374902_1472844906
# 799 2016-09-02  8885051388942907862  8885051388942907862_1472827393
# 802 2016-09-02   185467632009737931  0185467632009737931_1472846398
# 859 2016-09-02  3244885836845029978  3244885836845029978_1472824817
#
#     channelGrouping  visitStartTime device.browser device.operatingSystem  \
# 752          Direct      1472843572         Chrome                  Linux
# 753  Organic Search      1472844906         Chrome              Macintosh
# 799        Referral      1472827393         Chrome                  Linux
# 802        Referral      1472846398         Chrome                Windows
# 859        Referral      1472824817         Chrome              Macintosh
#
#      device.isMobile device.deviceCategory geoNetwork.subContinent  ...  \
# 752            False               desktop        Northern America  ...
# 753            False               desktop        Northern America  ...
# 799            False               desktop        Northern America  ...
# 802            False               desktop        Northern America  ...
# 859            False               desktop        Northern America  ...
#
#     is_month_start is_month_end visitHour                  ts  \
# 752          False        False        19 2016-09-02 19:12:52
# 753          False        False        19 2016-09-02 19:35:06
# 799          False        False        14 2016-09-02 14:43:13
# 802          False        False        19 2016-09-02 19:59:58
# 859          False        False        14 2016-09-02 14:00:17
#
#      first_invate_month  first_invate_day     first_invate_ts first_buy_month  \
# 752             2016-09        2016-09-02 2016-09-02 19:12:52         2016-09
# 753             2016-09        2016-09-02 2016-09-02 19:35:06         2016-09
# 799             2016-08        2016-08-06 2016-08-06 18:42:52         2016-08
# 802             2016-08        2016-08-30 2016-08-30 19:14:03         2016-09
# 859             2016-08        2016-08-19 2016-08-19 19:36:37         2016-08
#
#     first_buy_day        first_buy_ts
# 752    2016-09-02 2016-09-02 19:12:52
# 753    2016-09-02 2016-09-02 19:35:06
# 799    2016-08-12 2016-08-12 23:02:40
# 802    2016-09-02 2016-09-02 19:59:58
# 859    2016-08-22 2016-08-22 18:50:23
#
# [5 rows x 39 columns]

# %%
(df_buy.first_invate_day != df_buy.first_buy_day).mean()
# Out:
# 0.34355188884064264

# %% [markdown]
# Сколько дней проходит от первого захода на сайт до первой покупки?

# %%
(df_buy['first_buy_ts'] - df_buy['first_invate_ts']).head()
# Out:
# 752   0 days 00:00:00
# 753   0 days 00:00:00
# 799   6 days 04:19:48
# 802   3 days 00:45:55
# 859   2 days 23:13:46
# dtype: timedelta64[ns]

# %%
df_buy['deltatime_buy'] = (df_buy['first_buy_ts'] - df_buy['first_invate_ts'])/np.timedelta64(1,'D')

df_buy['deltatime_buy'].hist(bins=30)
plt.xlabel('Время между первой покупкой и входом на сайт');

# %%
df_buy['deltatime_buy'].describe()
# Out:
# count    11515.000000
# mean         9.056645
# std         28.007666
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.823142
# max        351.061875
# Name: deltatime_buy, dtype: float64

# %% [markdown]
# Выбросы сильно искажают среднее.

# %% [markdown]
# А часов?

# %%
df_buy['deltatime_buy'] = (df_buy['first_buy_ts'] - df_buy['first_invate_ts'])/np.timedelta64(1,'h')
df_buy['deltatime_buy'].hist(bins=30)
plt.xlabel('Время между первой покупкой и входом на сайт');

# %%
df_buy['deltatime_buy'].describe()
# Out:
# count    11515.000000
# mean       217.359469
# std        672.183991
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         91.755417
# max       8425.485000
# Name: deltatime_buy, dtype: float64

# %%
df_buy['deltatime_buy'].quantile(0.6)
# Out:
# 2.1727777777777777

# %% [markdown]
# Видим, что свою первую покупку пользователи совершают чаще всего в первый же визит. В $40\%$ случаев между визитом, когда была совершена покупка и первым визитом проходит больше 2 часов. Также мы видим, что хвост у распределения оказывается довольно большим.

# %% [markdown]
# Посмотрим на динамику покупок.

# %%
df_buy.groupby('date')['fullVisitorId'].count().plot(figsize=(12,6));

# %% [markdown]
# График покупок не отличается существенно от графика визитов в плане своей динамики. Посмотрим на то, как покупки распределены по дням недели и часам.

# %%
df_buy.pivot_table(
    index = 'visitHour',
    columns = 'visitWeekday',
    values = 'totals.transactionRevenue',
    aggfunc='sum'
).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_feb87e48_17c8_11eb_b385_0242ac110007row0_col0 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row0_col1 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row0_col2 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row0_col3 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row0_col4 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row0_col5 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row1_col0 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row1_col1 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row1_col2 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row1_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row1_col4 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row1_col5 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row1_col6 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row2_col0 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row2_col1 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row2_col2 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row2_col3 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row2_col4 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row2_col5 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row2_col6 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row3_col0 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row3_col1 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row3_col2 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row3_col3 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row3_col4 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row3_col5 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row3_col6 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row4_col0 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row4_col1 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row4_col2 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row4_col3 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row4_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row4_col5 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row4_col6 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row5_col0 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row5_col1 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row5_col2 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row5_col3 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row5_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row5_col5 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row5_col6 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row6_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row6_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row6_col2 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row6_col3 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row6_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row6_col5 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row6_col6 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row7_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row7_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row7_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row7_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row7_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row7_col5 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row7_col6 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row8_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row8_col1 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row8_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_feb87e48_17c8_11eb_b385_0242ac110007row8_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;

# %% [markdown]
# C 17 до 23 часов видим самое большое число покупок.

# %% [markdown]
# ## 3.2  Сколько раз покупают за период?
#
# Посчитаем статистику о покупках в разбиении по когортам. Когорта - месяц первой покупки.

# %%
sales = df_buy.pivot_table(
    index='first_buy_month',
    columns='month',
    values = 'fullVisitorId',
    aggfunc='nunique'
)

plt.figure(figsize=(10, 8))
sns.heatmap(
    sales,
    annot=True,
    fmt='.0f',
    linewidths=1, 
    linecolor='black', 
    cmap="YlGnBu"
);

# %% [markdown]
# Снова видим, что интерес к магазину падает уже на второй месяц.

# %% [markdown]
# ## 3.3  Средний доход
#
# Посчитаем его на дневной основе.

# %%
g = (
    df_buy.groupby('date')
    .agg({'totals.transactionRevenue':'mean'})
    .plot(figsize=(12,6))
)

# %% [markdown]
# Посчитаем сколько денег приносят в среднем отдельные когорты. Для этого посчитаем суммарную выручку с каждой и поделим на число пользователей в ней.

# %%
sales_sum = df_buy.pivot_table(
    index='first_buy_month',
    columns='month',
    values = 'totals.transactionRevenue',
    aggfunc='sum'
)

plt.figure(figsize=(10, 8))
sns.heatmap(
    sales_sum/sales,
    annot=True,
    fmt='.0f',
    linewidths=1, 
    linecolor='black', 
    cmap="YlGnBu"
);

# %% [markdown]
# Есть несколько покупок на очень крупную сумму в февральской когорте.

# %% [markdown]
# # 4. Анализ выручки в разбивке по источникам
#
# > Проанализируем выручку в разбивке по её источникам.

# %%
df_buy['totals.transactionRevenue'] = df_buy['totals.transactionRevenue'].apply(lambda w: np.log(w + 1))

# %% [markdown]
# Посмотрим какие браузеры самые популярные.

# %%
df_buy['device.browser'].value_counts()[:10]
# Out:
# Chrome               10353
# Safari                 780
# Firefox                191
# Internet Explorer      109
# Edge                    58
# Safari (in-app)         12
# Android Webview          6
# Opera                    5
# Amazon Silk              1
# Name: device.browser, dtype: int64

# %%
plt.figure(figsize=(12,6))

df_buy['device.browser'].value_counts().plot(kind='bar')

plt.title("TOP 10 самых используемых браузеров", fontsize=20)
plt.xlabel("Браузер", fontsize=16)
plt.ylabel("Число визитов", fontsize=16);

# %% [markdown]
# Выручка с разбивкой по браузерам

# %%
plt.figure(figsize=(12,6))

data = (df_buy[
    df_buy['device.browser'].isin(
        df_buy['device.browser'].value_counts()[:10].index.values
    )]
)

g = sns.boxplot(x='device.browser', 
              y='totals.transactionRevenue', 
              data=data);

g.set_title('Выручка в разбивке по браузерам', fontsize=20)
g.set_xlabel('Браузер', fontsize=18)
g.set_ylabel('Распределение выручки', fontsize=18);

# %% [markdown]
# Посмотрим на операционные системы.

# %%
plt.figure(figsize=(12,6))

df_buy['device.operatingSystem'].value_counts().plot(kind='bar')

plt.title("Операционная система", fontsize=20)
plt.xlabel("Операционная система", fontsize=16)
plt.ylabel("Число визитов", fontsize=16);

# %% [markdown]
# Прибыль по разным операционным системам

# %%
data = (
    df_buy[
        df_buy['device.operatingSystem']
       .isin(df_buy['device.operatingSystem'].value_counts()[:6].index.values)
          ]
)


# Такой же приём можно использовать и для графиков
g = ( 
    sns.FacetGrid(data, hue='device.operatingSystem', aspect=2)
    .map(sns.kdeplot, 'totals.transactionRevenue', shade=True)
    .add_legend()
);

# %% [markdown]
# Выручка в разбивке по разным типам устройств.

# %%
sns.countplot(df_buy["device.deviceCategory"], palette="hls");

# %%
plt.figure(figsize=(12,6))

g = sns.boxplot(x='device.deviceCategory', 
              y='totals.transactionRevenue', 
              data=df_buy);

g.set_title('Выручка в разбивке по типам устройств', fontsize=20)
g.set_xlabel('Устройство', fontsize=18)
g.set_ylabel('Распределение выручки', fontsize=18);

# %%
g = (
    sns.FacetGrid(df_buy, hue='device.deviceCategory', aspect=2)
    .map(sns.kdeplot, 'totals.transactionRevenue', shade=True)
    .add_legend()
);

# %% [markdown]
# Из каких городов чаще всего делаются покупки.

# %%
# !pip install squarify

# %%
df_buy["geoNetwork.city"].value_counts()
# Out:
# not available in demo dataset    4579
# New York                         1506
# Mountain View                    1209
# San Francisco                     729
# Sunnyvale                         455
#                                  ...
# Sacramento                          1
# Warsaw                              1
# Indianapolis                        1
# Fort Collins                        1
# San Marcos                          1
# Name: geoNetwork.city, Length: 134, dtype: int64

# %%
# !pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
import squarify

df_cur = df_buy[df_buy["geoNetwork.city"] != 'not available in demo dataset']

# %%
city_tree = df_cur["geoNetwork.city"].value_counts()
city_tree = round((city_tree[:30] / len(df_cur['geoNetwork.city']) * 100),2)

plt.figure(figsize=(12,12))

g = squarify.plot(
    sizes=city_tree.values, 
    label=city_tree.index, 
    value=city_tree.values,
    alpha=.3
)

g.set_title("Топ-30 городов по выручке - % от общей суммы", fontsize=20)
g.set_axis_off();
